# %%
subjects = ["Python", "Math", "AI", "Data"]
print(subjects)
print(subjects[-1])
print(subjects[0])
# Out:
# ['Python', 'Math', 'AI', 'Data']
# Data
# Python

# %%
college={}
college["city"]="mathura"
college["grades"]=["A+","A","B"]
college["name"]="GLA"

dict1 ={"name":"Rahul",
       "marks" :"CA",
       "grade":"O"
       }
dict2 ={"name":"Lokesh",
       "marks" :"CA",
       "grade":"B"
       }
dict3 ={"name":"Lakshya",
       "marks" :"CA",
       "grade":"A"
       }
lst=[dict1,dict2,dict3]
for i in lst:
  if(i["grade"]=="O"):
    print(i.get("name"))
# Out:
# Rahul

# %%
marks = 72
if(marks>80):
  print("distinction")
elif marks>=40:
  print("Pass")
else:
  print("Fail")
if(marks%2==0):
  print("even")
else:
  print("odd")
# Out:
# Pass
# even

# %%
age=45
if(age>19):
  print("adult")
elif(age>13 and age<=19):
  print("teenager")
else:
  print("child")
# Out:
# adult

# %%
students = [
    {"Name": "fuck", "City": "Mathura", "Grade": "A+",},
    {"Name": "mko", "City": "Agra", "Grade": "B+"},
    {"Name": "wqe", "City": "Delhi", "Grade": "A"},
    {"Name": "bye", "City": "KANPUR", "Grade": "A+"},
    {"Name": "dua lipa", "City": "ALIGARH", "Grade": "B+"}
]

# %%
def res(marks):
    if marks < 40:
        return "Fail"
    else:
        return "Pass"
mark=int(input())
print(res(mark))
# Out:
# 49
# Pass

# %%
marks=45
result_lambda = lambda marks : "Pass" if marks > 40 else "Fail"
print(result_lambda(marks))
# Out:
# Pass

# %%
import numpy as np

# %%
marks = np.array([78,91,55,72,40,88])
marks_2d = marks.reshape(3, 2)
print(marks_2d)
# Out:
# [[78 91]
#  [55 72]
#  [40 88]]

# %%
import pandas as pd

df = pd.read_csv("/content/session4_dummy_students_data.csv.xls")
print(df)
df.info()
science_scores = df['science'].to_numpy()
math_scores = df['math'].to_numpy()
english_scores = df['english'].to_numpy()
print(science_scores)
print(type(science_scores))
print(science_scores.mean())
df["average_score"] = (df["math"] + df["science"] + df["english"]) / 3
print(df["average_score"])

top_students=df[df["average_score"]>=85]
print(top_students[["name","average_score"]])

top_students = df[df['average_score']>85]
print(top_students)
low_attendance = df[df['attendance_percent'] < 75]
print(low_attendance)
student_city = df[df['city'] == "Mathura"]
print(student_city)
# Out:
#     student_id    name  age     city  math  science  english  \
# 0          101   Aarav   16   Mumbai    78       84       69
# 1          102    Diya   16    Delhi    91       88       94
# 2          103   Kabir   17  Mathura    55       61       58
# 3          104   Meera   16    Noida    72       79       81
# 4          105   Rohan   17   Mumbai    40       52       47
# 5          106    Sara   16    Delhi    88       93       90
# 6          107  Ishaan   17  Mathura    64       70       66
# 7          108  Ananya   16    Noida    95       92       89
# 8          109  Vivaan   17   Mumbai    48       57       51
# 9          110    Tara   16    Delhi    83       76       85
# 10         111   Arjun   17  Mathura    67       63       72
# 11         112   Nisha   16    Noida    74       81       79
# 12         113     Dev   17   Mumbai    35       45       42
# 13         114   Priya   16    Delhi    89       86       91
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/session4_dummy_students_data.csv.xls")

df["average"] = (df["math"] + df["science"] + df["english"]) / 3

df["result"] = df["average"].apply(lambda avg: "Pass" if avg >= 40 else "Fail")

class_avg = df["average"].mean()
highest_avg = df["average"].max()
lowest_avg = df["average"].min()

print(f"Class Average: {class_avg:.2f}")
print(f"Highest Average: {highest_avg:.2f}")
print(f"Lowest Average: {lowest_avg:.2f}")

top_students = df[df["average"] == highest_avg]
print("\nTop Student(s):")
print(top_students[["name", "average"]])

low_attendance = df[df["attendance_percent"] < 75]
print("\nStudents with Attendance Below 75:")
print(low_attendance[["name", "attendance_percent"]])

few_assignments = df[df["assignments_submitted"] < 6]
print("\nStudents with Fewer Than 6 Assignments Submitted:")
print(few_assignments[["name", "assignments_submitted"]])

df.to_csv("session4_student_report.csv", index=False)
print("\nFinal output saved as session4_student_report.csv")
# Out:
# Class Average: 71.35
# Highest Average: 92.67
# Lowest Average: 40.67
#
# Top Student(s):
#     name    average
# 15  Riya  92.666667
#
# Students with Attendance Below 75:
#       name  attendance_percent
# 4    Rohan                  68
# 8   Vivaan                  71
# 12     Dev                  62
# 18    Yash                  66
#
# Students with Fewer Than 6 Assignments Submitted:
#      name  assignments_submitted
# 4   Rohan                      5
# 12    Dev                      4
# 18   Yash                      5
#
# Final output saved as session4_student_report.csv

# %%
import pandas as pd

df = pd.read_csv("/content/session4_dummy_students_data.csv.xls")

df["average"] = (df["math"] + df["science"] + df["english"]) / 3
df["result"] = "Fail"
df.loc[df["average"] >= 40, "result"] = "Pass"

print(df["average"].mean())
print(df["average"].max())
print(df["average"].min())
top_students = df[df["average"] == df["average"].max()]
print(top_students)
print(df[df["attendance_percent"] < 75])
print(df[df["assignments_submitted"] < 6])
# Out:
# 71.35000000000001
# 92.66666666666667
# 40.666666666666664
#     student_id  name  age   city  math  science  english  attendance_percent  \
# 15         116  Riya   16  Noida    92       90       96                  98
#
#     study_hours_per_week  assignments_submitted  final_project_score  \
# 15                    13                     10                   96
#
#       average result
# 15  92.666667   Pass
#     student_id    name  age     city  math  science  english  \
# 4          105   Rohan   17   Mumbai    40       52       47
# 8          109  Vivaan   17   Mumbai    48       57       51
# 12         113     Dev   17   Mumbai    35       45       42
# 18         119    Yash   17  Mathura    43       49       46
#
#     attendance_percent  study_hours_per_week  assignments_submitted  \
# 4                   68                     3                      5
# 8                   71                     4                      6
# ...

# %%
#Questions
1. Can data about countries help us compare development over time
2.Would GDP per capita alone be enough or do we need more features

healthcare
literacy
Population
education?
employement rate

healthcare
mortality rate
BMI
life expectancy
cost of treatment


mortality rate
infant mortality rate
maternal mortality rate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url="https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"

df=pd.read_csv(url)


print(df.head())
print(df.shape)
print(df.columns)
print(df.info())
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# (1704, 6)
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# ...

# %%
df = df.rename(columns={
    "lifeExp": "life_expectancy",
    "pop": "population",
    "gdpPercap": "gdp_per_capita"
})

print(df.head())
print(df.columns)
# Out:
#        country  year  population continent  life_expectancy  gdp_per_capita
# 0  Afghanistan  1952   8425333.0      Asia           28.801      779.445314
# 1  Afghanistan  1957   9240934.0      Asia           30.332      820.853030
# 2  Afghanistan  1962  10267083.0      Asia           31.997      853.100710
# 3  Afghanistan  1967  11537966.0      Asia           34.020      836.197138
# 4  Afghanistan  1972  13079460.0      Asia           36.088      739.981106
# Index(['country', 'year', 'population', 'continent', 'life_expectancy',
#        'gdp_per_capita'],
#       dtype='object')

# %%
print("Missing values in each column:")
print(df.isna().sum)

print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Missing values in each column:
# <bound method DataFrame.sum of       country   year  population  continent  life_expectancy  gdp_per_capita
# 0       False  False       False      False            False           False
# 1       False  False       False      False            False           False
# 2       False  False       False      False            False           False
# 3       False  False       False      False            False           False
# 4       False  False       False      False            False           False
# ...       ...    ...         ...        ...              ...             ...
# 1699    False  False       False      False            False           False
# 1700    False  False       False      False            False           False
# 1701    False  False       False      False            False           False
# 1702    False  False       False      False            False           False
# ...

# %%
df_clean = df.copy()

# Remove exact duplicate rows if any
if df_clean.duplicated().sum() > 0:
    df_clean = df_clean.drop_duplicates()

# Strip extra spaces from text columns
for col in ["country", "continent"]:
    df_clean[col] = df_clean[col].astype(str).str.strip()

# Ensure expected data types
df_clean["year"] = df_clean["year"].astype(int)
df_clean["population"] = df_clean["population"].astype(float)
df_clean["life_expectancy"] = df_clean["life_expectancy"].astype(float)
df_clean["gdp_per_capita"] = df_clean["gdp_per_capita"].astype(float)

print(df_clean.dtypes)
print(df_clean.head())
# Out:
# country             object
# year                 int64
# population         float64
# continent           object
# life_expectancy    float64
# gdp_per_capita     float64
# dtype: object
#        country  year  population continent  life_expectancy  gdp_per_capita
# 0  Afghanistan  1952   8425333.0      Asia           28.801      779.445314
# 1  Afghanistan  1957   9240934.0      Asia           30.332      820.853030
# 2  Afghanistan  1962  10267083.0      Asia           31.997      853.100710
# 3  Afghanistan  1967  11537966.0      Asia           34.020      836.197138
# 4  Afghanistan  1972  13079460.0      Asia           36.088      739.981106

# %%
dirty_demo = df_clean.head(12).copy()

# Deliberately introduce missing values for teaching practice
dirty_demo.loc[2, "life_expectancy"] = np.nan
dirty_demo.loc[5, "gdp_per_capita"] = np.nan

print(dirty_demo)
print(dirty_demo.isna().sum())

# Fill missing numerical values using median
clean_demo = dirty_demo.copy()
clean_demo["life_expectancy"] = clean_demo["life_expectancy"].fillna(clean_demo["life_expectancy"].median())
clean_demo["gdp_per_capita"] = clean_demo["gdp_per_capita"].fillna(clean_demo["gdp_per_capita"].median())

print(clean_demo.isna().sum())
print(clean_demo)
# Out:
#         country  year  population continent  life_expectancy  gdp_per_capita
# 0   Afghanistan  1952   8425333.0      Asia           28.801      779.445314
# 1   Afghanistan  1957   9240934.0      Asia           30.332      820.853030
# 2   Afghanistan  1962  10267083.0      Asia              NaN      853.100710
# 3   Afghanistan  1967  11537966.0      Asia           34.020      836.197138
# 4   Afghanistan  1972  13079460.0      Asia           36.088      739.981106
# 5   Afghanistan  1977  14880372.0      Asia           38.438             NaN
# 6   Afghanistan  1982  12881816.0      Asia           39.854      978.011439
# 7   Afghanistan  1987  13867957.0      Asia           40.822      852.395945
# 8   Afghanistan  1992  16317921.0      Asia           41.674      649.341395
# 9   Afghanistan  1997  22227415.0      Asia           41.763      635.341351
# 10  Afghanistan  2002  25268405.0      Asia           42.129      726.734055
# ...

# %%
import pandas as pd
url="https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"

df=pd.read_csv(url)

# Year range
min_year = df['year'].min()
max_year = df['year'].max()

print("Year Range:", min_year, "-", max_year)

# Number of countries
num_countries = df['country'].nunique()
print("Number of Countries:", num_countries)

# Number of continents
num_continents = df['continent'].nunique()
print("Number of Continents:", num_continents)
# Out:
# Year Range: 1952 - 2007
# Number of Countries: 142
# Number of Continents: 5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # Import seaborn
url="https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"

df=pd.read_csv(url)
avg_life_expectancy_by_continent = df.groupby('continent')['lifeExp'].mean().reset_index() # Changed 'life_expectancy' to 'lifeExp'

plt.figure(figsize=(8,5))
sns.barplot(x='continent', y='lifeExp', data=avg_life_expectancy_by_continent, palette='viridis') # Changed 'life_expectancy' to 'lifeExp'
plt.title('Average Life Expectancy by Continent')
plt.xlabel('Continent')
plt.ylabel('Average Life Expectancy')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2284/664930539.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='continent', y='lifeExp', data=avg_life_expectancy_by_continent, palette='viridis') # Changed 'life_expectancy' to 'lifeExp'

# %%
# Filter data for India, China, and USA
countries_of_interest = ['India', 'China', 'United States']
df_filtered = df[df['country'].isin(countries_of_interest)]

plt.figure(figsize=(12, 7))
sns.lineplot(data=df_filtered, x='year', y='lifeExp', hue='country', marker='o')
plt.title('Life Expectancy Trends in India, China, and USA (1952-2007)')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Country')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='gdpPercap', y='lifeExp', hue='continent', size='pop', sizes=(20, 400), alpha=0.7)
plt.xscale('log') # GDP per capita often benefits from a log scale due to its wide range
plt.title('GDP per Capita vs. Life Expectancy (1952-2007)')
plt.xlabel('GDP per Capita (log scale)')
plt.ylabel('Life Expectancy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Continent', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
